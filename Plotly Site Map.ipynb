# %% [markdown]
# # 3 piliers of dash
# 1. Dash components
#     - [documentation](https://dash.plotly.com/dash-core-components)
#     - [github](https://github.com/plotly/dash)
# 2. Plotly Graphs
# 3. Callback

# %% [markdown]
# # URLs
#
# Intro to Dash Plotly - Youtube:
# https://www.youtube.com/watch?v=hSPmj7mK6ng&t=1165s
#
# The Code:
# https://github.com/Coding-with-Adam/D...
#
# View my book - The Book of Dash:
# https://www.amazon.com/Python-Dash-An...
# https://github.com/DashBookProject/Pl...
#
# The Data:
# https://drive.google.com/file/d/19xeI...
#
# Dash App Gallery:
# https://dash-gallery.plotly.host/Portal/
#
# Dash Components:
# https://dash.plotly.com/dash-core-com...
#
# Plotly Graphs:
# https://plotly.com/python/
#
# The Callback:
# https://dash.plotly.com/basic-callbacks
#
# Plotly Express:
# https://plotly.com/python-api-referen...
#
# Dash Plotly Community Forum:
# https://community.plotly.com/c/dash/16

# %% [markdown]
# # Plotly Graphs
# - [fundamentals](https://plotly.com/python/plotly-fundamentals/)
# ![image.png](attachment:image.png)
# - [basic charts](https://plotly.com/python/basic-charts/)
# ![image-2.png](attachment:image-2.png)
# - [Statistical Chart](https://plotly.com/python/statistical-charts/)
# ![image-3.png](attachment:image-3.png)
# - [Subplots](https://plotly.com/python/#subplot-charts)
# ![image-4.png](attachment:image-4.png)
